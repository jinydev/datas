# %% [markdown]
# # 01. 엑셀을 넘어서 (Pandas 기초)
# 데이터프레임을 생성하고 기본적인 정보를 확인해봅니다.

# %%
import pandas as pd

# 데이터프레임 생성
data = {
    '이름': ['김철수', '이영희', '박민수', '최지우', '정우성'],
    '나이': [25, 30, 22, 28, 45],
    '직업': ['학생', '회사원', '학생', '디자이너', '배우'],
    '점수': [80, 95, 70, 85, 99]
}
df = pd.DataFrame(data)

# 9. 상위 데이터 확인
df.head()

# %%
# 11. 메타데이터 정보 확인
df.info()

# %%
# 12. 기술 통계량 확인
df.describe()

# %%
# 13. 특정 컬럼 선택
df['이름']
