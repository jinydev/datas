# %% [markdown]
# # 02. 데이터 탐색하기
# loc, 일oc, 그리고 불리언 인덱싱을 이용한 필터링 기법.

# %%
import pandas as pd

# 샘플 데이터
data = {
    '이름': ['김철수', '이영희', '박민수', '최지우', '정우성'],
    '나이': [25, 30, 22, 28, 45],
    '직업': ['학생', '회사원', '학생', '디자이너', '배우'],
    '점수': [80, 95, 70, 85, 99]
}
df = pd.DataFrame(data)
df

# %%
# 7. 불리언 인덱싱 (점수 90점 이상)
df[df['점수'] >= 90]

# %%
# 10. 다중 조건 (직업이 학생이고 점수가 75점 이상)
cond = (df['직업'] == '학생') & (df['점수'] >= 75)
df[cond]

# %%
# 15. 정렬 (점수 높은 순)
df.sort_values(by='점수', ascending=False)
