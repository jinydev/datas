# %% [markdown]
# # Final Project: [본인의 주제를 적으세요]
# **이름**: 홍길동
# **날짜**: 202X.XX.XX
#
# ## 1. 프로젝트 개요
# - **목표**: (예: 타이타닉 승객 생존 여부 예측)
# - **데이터셋**: (예: Kaggle Titanic Dataset)
# - **방법론**: (예: Random Forest, XGBoost)

# %% [markdown]
# ## 2. 라이브러리 및 데이터 로드

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 한글 폰트 설정 (Colab용)
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
plt.rc('font', family='NanumBarunGothic') 

# 데이터 로드
# df = pd.read_csv('drive/MyDrive/data.csv')
df = pd.DataFrame({'a':[1,2], 'b':[3,4]}) # 예시
df.head()

# %% [markdown]
# ## 3. EDA (탐색적 데이터 분석)

# %%
df.info()
df.describe()

# %% [markdown]
# ## 4. 데이터 전처리 및 피처 엔지니어링

# %%
# 결측치 처리, 인코딩, 스케일링 등 수행

# %% [markdown]
# ## 5. 모델링 및 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# X_train, X_test, y_train, y_test = ...

# %% [markdown]
# ## 6. 결론 및 제언
# - 분석 결과 요약
# - 비즈니스 인사이트 도출
