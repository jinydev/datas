# %% [markdown]
# # 04. 자동화와 반복문
# For 반복문을 이용한 패턴 생성 및 누적 계산.

# %%
import matplotlib.pyplot as plt
import random

# 13. 응용 예제: 제너레이티브 아트
plt.figure(figsize=(6, 6))

# 2. for 반복문으로 50개의 선 그리기
for i in range(50):
    x1 = random.randint(0, 10)
    y1 = random.randint(0, 10)
    x2 = random.randint(0, 10)
    y2 = random.randint(0, 10)
    
    # 5. i값을 이용해 색상 변화 주기
    red_intensity = i / 50.0 
    
    plt.plot([x1, x2], [y1, y2], color=(red_intensity, 0, 0.5), alpha=0.5)

plt.title("Generative Net Art")
plt.axis('off')
plt.show()

# %%
# 7. 누적 패턴 (합계)
scores = [80, 90, 95, 70, 60]
total = 0

print("=== 합계 구하기 로직 ===")
for s in scores:
    print(f"{s} 점을 더합니다. (현재 누적: {total})")
    total += s 

print(f"최종 합계: {total}")
print(f"평균 점수: {total / len(scores)}")
