# %% [markdown]
# # 06. Lab: 타이타닉 심층 리포트
# 전처리 파이프라인 구축 및 주요 가설(성별, 계급, 가족) 검증.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 로드
df = sns.load_dataset('titanic')

# 파생변수 생성
df['family_size'] = df['sibsp'] + df['parch'] + 1

# 시각화 1: 가족 규모별 생존율
plt.figure(figsize=(8, 5))
sns.pointplot(x='family_size', y='survived', data=df)
plt.title('Survival by Family Size')
plt.grid(True)
plt.show()

# %%
# 시각화 2: 나이대별 생존자 분포
plt.figure(figsize=(8, 5))
sns.kdeplot(df[df['survived']==1]['age'], shade=True, label='Survived')
sns.kdeplot(df[df['survived']==0]['age'], shade=True, label='Dead')
plt.legend()
plt.title('Age Distribution')
plt.show()
