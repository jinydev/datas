# %% [markdown]
# # 5.1.5 그래프 속성과 스타일링 실습
#
# 이 노트북은 Matplotlib의 다양한 속성을 조합하여 나만의 디자인이 들어간 커스텀 차트를 그리는 과정을 실습합니다.

# %% [markdown]
# ### 🚨 트러블슈팅: `ModuleNotFoundError` 가 발생할 때
#
# 아래 셀에서 에러가 발생한다면, 이 셀의 주석을 풀고 한 번 실행하여 패키지를 설치해 주세요.

# %%
# 처음 실행 시 에러가 난다면 아래 주석을 풀고 설치하세요!
# %pip install matplotlib

# %% [markdown]
# ## [실습 1] 스타일링 종합 실습
#
# 용사와 몬스터의 레벨별 체력을 비교하는 차트를 각 특성에 맞게 색상, 선스타일, 마커를 바꾸어 그려봅니다.

# %%
import matplotlib.pyplot as plt

# 한글 폰트 설정
plt.rcParams['font.family'] = 'AppleGothic' # 윈도우는 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
# %config InlineBackend.figure_format = 'retina'

# 데이터 준비
level = [1, 2, 3, 4, 5]
hero_hp = [100, 120, 150, 190, 240]    # 용사 체력
monster_hp = [80, 130, 200, 300, 450]  # 몬스터 체력

plt.figure(figsize=(8, 5))

# 용사: 파란색 실선, 원(circle) 마커, 선굵기 2
plt.plot(level, hero_hp, label='Hero (용사)', c='b', ls='-', marker='o', lw=2)

# 몬스터: 빨간색 쇄선, X 마커, 선굵기 2
plt.plot(level, monster_hp, label='Monster (괴물)', c='r', ls='-.', marker='x', lw=2)

# 제목 및 축 레이블 꾸미기
plt.title("Hero vs Monster HP Growth", fontsize=15)
plt.xlabel("Level", fontsize=12)
plt.ylabel("HP", fontsize=12)

# 범례 표시 및 그리드 설정
plt.legend(fontsize=11)
plt.grid(True, axis='y', linestyle=':', alpha=0.5)

plt.show()
